# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv', index_col=0)
data.head()
# Out:
#                State  Customer Lifetime Value Response  Coverage Education  \
# Customer
# BU79786   Washington              2763.519279       No     Basic  Bachelor
# QZ44356      Arizona              6979.535903       No  Extended  Bachelor
# AI49188       Nevada             12887.431650       No   Premium  Bachelor
# WW63253   California              7645.861827       No     Basic  Bachelor
# HB64268   Washington              2813.692575       No     Basic  Bachelor
#
#          Effective To Date EmploymentStatus Gender  Income Location Code  ...  \
# Customer                                                                  ...
# BU79786            2/24/11         Employed      F   56274      Suburban  ...
# QZ44356            1/31/11       Unemployed      F       0      Suburban  ...
# AI49188            2/19/11         Employed      F   48767      Suburban  ...
# WW63253            1/20/11       Unemployed      M       0      Suburban  ...
# ...

# %%
#Get the numerical variables from our dataset.

# %%
numeric = data.select_dtypes(include=[int, float])
numeric.head()
# Out:
#           Customer Lifetime Value  Income  Monthly Premium Auto  \
# Customer
# BU79786               2763.519279   56274                    69
# QZ44356               6979.535903       0                    94
# AI49188              12887.431650   48767                   108
# WW63253               7645.861827       0                   106
# HB64268               2813.692575   43836                    73
#
#           Months Since Last Claim  Months Since Policy Inception  \
# Customer
# BU79786                        32                              5
# QZ44356                        13                             42
# AI49188                        18                             38
# WW63253                        18                             65
# HB64268                        12                             44
#
#           Number of Open Complaints  Number of Policies  Total Claim Amount
# Customer
# BU79786                           0                   1          384.811147
# ...

# %%
#Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
for col in numeric:
    sns.distplot(numeric[col], kde=True, hist=False)
    plt.title(f'Distribution of {col}')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_5552\4205335403.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numeric[col], kde=True, hist=False)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_5552\4205335403.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# Some are normal, some are exponential.

# %%
#Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.
numeric_log = numeric.apply(lambda x: np.log(x))
numeric_log.head()
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#           Customer Lifetime Value     Income  Monthly Premium Auto  \
# Customer
# BU79786                  7.924260  10.937988              4.234107
# QZ44356                  8.850738       -inf              4.543295
# AI49188                  9.464008  10.794809              4.682131
# WW63253                  8.941920       -inf              4.663439
# HB64268                  7.942253  10.688211              4.290459
#
#           Months Since Last Claim  Months Since Policy Inception  \
# Customer
# BU79786                  3.465736                       1.609438
# QZ44356                  2.564949                       3.737670
# AI49188                  2.890372                       3.637586
# ...

# %%
for col in numeric_log:
    sns.distplot(numeric_log[col], kde=True, hist=False)
    plt.title(f'Distribution of {col}')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_5552\1047988061.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numeric_log[col], kde=True, hist=False)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_5552\1047988061.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# Yes, they changed.
