# %%
import pandas as pd

# %%
data =  pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
#1. Get the numerical variables from our dataset.
numerical = data._get_numeric_data()
numerical.head()
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
#2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
import matplotlib.pyplot as plt
def plot_continuous_variables(numerical):
    
    for col in numerical.columns:
        plt.figure()
        plt.title(col)
        numerical[col].plot(kind='hist')
        
plot_continuous_variables(numerical)

# %%
#All fof the distribitions are skewed, exponentially decreasing.
#Only Months Since Policy Inception might seem almost normal

# %%
#3. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
numerical.isna().sum()
# Out:
# Customer Lifetime Value          0
# Income                           0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Total Claim Amount               0
# dtype: int64

# %%
import numpy as np

# apply log-transform to numerical columns
import pandas as pd
import numpy as np

# replace non-positive values with a small positive value
numerical[["Income", "Monthly Premium Auto", "Months Since Last Claim",
      "Months Since Policy Inception", "Number of Open Complaints",
      "Number of Policies", "Total Claim Amount"]] = \
    numerical[["Income", "Monthly Premium Auto", "Months Since Last Claim",
          "Months Since Policy Inception", "Number of Open Complaints",
          "Number of Policies", "Total Claim Amount"]].apply(lambda x: np.where(x <= 0, 1e-6, x))

# apply log-transform to numerical columns
numerical[["Income", "Monthly Premium Auto", "Months Since Last Claim",
      "Months Since Policy Inception", "Number of Open Complaints",
      "Number of Policies", "Total Claim Amount"]] = \
    np.log(numerical[["Income", "Monthly Premium Auto", "Months Since Last Claim",
                 "Months Since Policy Inception", "Number of Open Complaints",
                 "Number of Policies", "Total Claim Amount"]])

numerical.head()
# Out:
#    Customer Lifetime Value     Income  Monthly Premium Auto  \
# 0              2763.519279   2.392242              1.443172
# 1              6979.535903 -13.815511              1.513652
# 2             12887.431650   2.379065              1.543753
# 3              7645.861827 -13.815511              1.539753
# 4              2813.692575   2.369141              1.456394
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                 1.242925                       0.475885
# 1                 0.941939                       1.318462
# 2                 1.061385                       1.291320
# 3                 1.061385                       1.428968
# 4                 0.910235                       1.330832
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                 -13.815511          -13.815511            1.783854
# 1                 -13.815511            0.732099            1.950367
# ...

# %%
import matplotlib.pyplot as plt
def plot_continuous_variables(numerical):
    
    for col in numerical.columns:
        plt.figure()
        plt.title(col)
        numerical[col].plot(kind='hist')
        
plot_continuous_variables(numerical)
