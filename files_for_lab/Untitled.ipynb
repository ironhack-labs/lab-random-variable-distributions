# %% [markdown]
# ![logo_ironhack_blue 7](https://user-images.githubusercontent.com/23629340/40541063-a07a0a8a-601a-11e8-91b5-2f13e4e6b441.png)
#
# # Lab | Random variable distributions
#
# Refer to the `files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv` dataset.
#
# ### Instructions
#
# 1. Get the numerical variables from our dataset.
# 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
# 3. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
import pandas as pd
import numpy as np
import snakecase
import stringcase
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### 1. Get the numerical variables from our dataset.
# ***

# %%
numerical = pd.read_csv('numericalsfinal.csv')
numerical.drop(['Unnamed: 0'],axis=1,inplace=True)
numerical
# Out:
#       customer__lifetime__value  income  monthly__premium__auto  \
# 0                   2763.519279   56274                      69
# 1                   6979.535903       0                      94
# 2                  12887.431650   48767                     108
# 3                   7645.861827       0                     106
# 4                   2813.692575   43836                      73
# ...                         ...     ...                     ...
# 9129               23405.987980   71941                      73
# 9130                3096.511217   21604                      79
# 9131                8163.890428       0                      85
# 9132                7524.442436   21941                      96
# 9133                2611.836866       0                      77
#
#       months__since__last__claim  months__since__policy__inception  \
# 0                             32                                 5
# 1                             13                                42
# 2                             18                                38
# 3                             18                                65
# 4                             12                                44
# ...                          ...                               ...
# 9129                          18                                89
# 9130                          14                                28
# 9131                           9                                37
# 9132                          34                                 3
# 9133                           3                                90
#
#       number_of__open__complaints  number_of__policies  total__claim__amount
# 0                               0                    1            384.811147
# 1                               0                    8           1131.464935
# 2                               0                    2            566.472247
# 3                               0                    7            529.881344
# 4                               0                    1            138.130879
# ...                           ...                  ...                   ...
# 9129                            0                    2            198.234764
# 9130                            0                    1            379.200000
# 9131                            3                    2            790.784983
# 9132                            0                    3            691.200000
# 9133                            0                    1            369.600000
#
# [9134 rows x 8 columns]

# %% [markdown]
# #### 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
# ***

# %%
for col in data:
    plt.hist(data[col], bins=10)
    plt.title(col)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0m/d3zbckcj1zd772z7m1w0_xgc0000gn/T/ipykernel_16407/3899670561.py in <module>
# ----> 1 for col in data:
#       2     plt.hist(data[col], bins=10)
#       3     plt.title(col)
#       4     plt.show()
#
# NameError: name 'data' is not defined

# %%
data = pd.read_csv('/Users/joao/Desktop/Ironhack/Mid Project/Data/mid_project_weather_data.csv')

# %%
sorted(data['name'].unique())
# Out:
# ['amsterdam',
#  'athens',
#  'belgrade',
#  'berlin',
#  'bern',
#  'brussels',
#  'bucharest',
#  'budapest',
#  'copenhagen',
#  'dublin',
#  'helsinki',
#  'kyiv',
#  'lisbon',
#  'ljubljana',
#  'london',
#  'luxembourg',
#  'madrid',
#  'minsk',
#  'oslo',
#  'paris',
#  'podgoica',
#  'prague',
#  'reykjavik',
#  'rome',
#  'sarajevo',
#  'skopje',
#  'sofia',
#  'stockholm',
#  'tallinn',
#  'tirana',
#  'valletta',
#  'vienna',
#  'vilnius',
#  'warsaw',
#  'zagreb']
